# %%
import tifffile

with tifffile.TiffFile("/home/duydao/Projects/xenium_lung/data/Xenium_V1_humanLung_Cancer_FFPE_outs/morphology_focus/morphology_focus_0001.ome.tif") as tif:
    print(tif.ome_metadata)
# Out:
# <OME xmlns="http://www.openmicroscopy.org/Schemas/OME/2016-06" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:schemaLocation="http://www.openmicroscopy.org/Schemas/OME/2016-06 http://www.openmicroscopy.org/Schemas/OME/2016-06/ome.xsd" UUID="urn:uuid:457ba90e-c18a-11ee-b6c4-06813654a7371">
#   <Plate ID="Plate:0" WellOriginX="0.0" WellOriginXUnit="µm" WellOriginY="0.0" WellOriginYUnit="µm"/>
#   <Instrument ID="Instrument:0">
#     <Microscope Manufacturer="10x Genomics" Model="Xenium"/>
#   </Instrument>
#   <Image ID="Image:0">
#     <InstrumentRef ID="Instrument:0"/>
#     <Pixels ID="Pixels:0" DimensionOrder="XYZCT" Type="uint16" SizeX="51187" SizeY="17098" SizeZ="1" SizeC="4" SizeT="1" PhysicalSizeX="0.2125" PhysicalSizeXUnit="µm" PhysicalSizeY="0.2125" PhysicalSizeYUnit="µm">
#       <Channel ID="Channel:0" Name="DAPI" SamplesPerPixel="1">
#         <AnnotationRef ID="Annotation:0"/>
#       </Channel>
#       <Channel ID="Channel:1" Name="18S" SamplesPerPixel="1">
# ...
